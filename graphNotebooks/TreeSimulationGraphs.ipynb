# %%
chainData = open("chainData.txt", "r")
treeData = open("randomTreeData.txt", "r")
fullData = open("fullTreeData.txt", "r")

# %%
chainFullTime = [float(line.strip().split()[2]) for line in chainData][::2]
chainData.seek(0, 0)
chainHalfTime = [float(line.strip().split()[2]) for line in chainData][1::2]
chainData.seek(0, 0)
chainFullCount = [float(line.strip().split()[3]) for line in chainData][::2]
chainData.seek(0, 0)
chainHalfCount = [float(line.strip().split()[3]) for line in chainData][1::2]
chainData.seek(0, 0)
# Out:
# 0

# %%
randomFullTime = [float(line.strip().split()[2]) for line in treeData][::2]
treeData.seek(0, 0)
randomHalfTime = [float(line.strip().split()[2]) for line in treeData][1::2]
treeData.seek(0, 0)
randomFullCount = [float(line.strip().split()[3]) for line in treeData][::2]
treeData.seek(0, 0)
randomHalfCount = [float(line.strip().split()[3]) for line in treeData][1::2]
treeData.seek(0, 0)
# Out:
# 0

# %%
fullFullTime = [float(line.strip().split()[2]) for line in fullData][::2]
fullData.seek(0, 0)
fullHalfTime = [float(line.strip().split()[2]) for line in fullData][1::2]
fullData.seek(0, 0)
fullFullCount = [float(line.strip().split()[3]) for line in fullData][::2]
fullData.seek(0, 0)
fullHalfCount = [float(line.strip().split()[3]) for line in fullData][1::2]

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)

yvalues = list(range(3, 36))
line, = ax.plot(yvalues, chainFullCount[:len(yvalues)], color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, chainHalfCount[:len(yvalues)], color='red', lw=2, label="half iteration")

chainTmp = chainHalfCount[3::2]

line3, = ax.plot(yvalues[:len(yvalues)], chainTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Number of points")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)

yvalues = list(range(3, 36))
line, = ax.plot(yvalues, chainFullTime[:len(yvalues)], color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, chainHalfTime[:len(yvalues)], color='red', lw=2, label="half iteration")

chainTmp = chainHalfTime[3::2]

line3, = ax.plot(yvalues, chainTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Time (mcs)")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)
yvalues = list(range(3, 36))

line, = ax.plot(yvalues, randomFullTime[:len(yvalues)], color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, randomHalfTime[:len(yvalues)], color='red', lw=2, label="half iteration")

randomTmp = randomHalfTime[3::2]

line3, = ax.plot(yvalues, randomTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Time (mcs)")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)

yvalues = list(range(3, 36))
line, = ax.plot(yvalues, randomFullCount[:len(yvalues)], color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, randomHalfCount[:len(yvalues)], color='red', lw=2, label="half iteration")

chainTmp = randomHalfCount[3::2]

line3, = ax.plot(yvalues, chainTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Number of points")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)
yvalues = list(range(3, 36))

line, = ax.plot(yvalues, fullFullTime[:len(yvalues)], color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, fullHalfTime[:len(yvalues)], color='red', lw=2, label="half iteration")

fullTmp = fullHalfTime[3::2]

line3, = ax.plot(yvalues, fullTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Time (mcs)")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)

yvalues = list(range(3, 36))
line, = ax.plot(yvalues, fullFullCount[:len(yvalues)], color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, fullHalfCount[:len(yvalues)], color='red', lw=2, label="half iteration")

chainTmp = fullHalfCount[3::2]

line3, = ax.plot(yvalues, chainTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Number of points")

ax.set_yscale('log')
plt.show()
