# %%
chainData = open("chainData.txt", "r")
treeData = open("randomTreeData.txt", "r")
fullData = open("fullTreeData.txt", "r")

# %%
chainFullTime = [float(line.strip().split()[2]) for line in chainData][::2]
chainData.seek(0, 0)
chainHalfTime = [float(line.strip().split()[2]) for line in chainData][1::2]
chainData.seek(0, 0)
chainFullCount = [float(line.strip().split()[3]) for line in chainData][::2]
chainData.seek(0, 0)
chainHalfCount = [float(line.strip().split()[3]) for line in chainData][1::2]
chainData.seek(0, 0)
# Out:
# 0

# %%
randomFullTime = [float(line.strip().split()[2]) for line in treeData][::2]
treeData.seek(0, 0)
randomHalfTime = [float(line.strip().split()[2]) for line in treeData][1::2]
treeData.seek(0, 0)
randomFullCount = [float(line.strip().split()[3]) for line in treeData][::2]
treeData.seek(0, 0)
randomHalfCount = [float(line.strip().split()[3]) for line in treeData][1::2]
treeData.seek(0, 0)
# Out:
# 0

# %%
fullFullTime = [float(line.strip().split()[2]) for line in fullData][::2]
fullData.seek(0, 0)
fullHalfTime = [float(line.strip().split()[2]) for line in fullData][1::2]
fullData.seek(0, 0)
fullFullCount = [float(line.strip().split()[3]) for line in fullData][::2]
fullData.seek(0, 0)
fullHalfCount = [float(line.strip().split()[3]) for line in fullData][1::2]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(chainFullTime, "r--")
plt.plot(chainHalfTime, "g*")
plt.xlabel("Depth of graph")
plt.ylabel("Time (mcs)")
plt.set_yscale('log')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-f95e15568071> in <module>
#       3 plt.xlabel("Depth of graph")
#       4 plt.ylabel("Time (mcs)")
# ----> 5 plt.set_yscale('log')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_yscale'

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)

yvalues = list(range(3, 36))
line, = ax.plot(yvalues, chainFullCount, color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, chainHalfCount, color='red', lw=2, label="half iteration")

chainTmp = chainHalfCount[16:]

line3, = ax.plot(yvalues[:17], chainTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Number of points")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)

yvalues = list(range(3, 36))
line, = ax.plot(yvalues, chainFullTime, color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, chainHalfTime, color='red', lw=2, label="half iteration")

chainTmp = chainHalfTime[16:]

line3, = ax.plot(yvalues[:17], chainTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Time (mcs)")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)
yvalues = list(range(3, 36))

line, = ax.plot(yvalues, randomFullTime, color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, randomHalfTime, color='red', lw=2, label="half iteration")

randomTmp = randomHalfTime[16:]

line3, = ax.plot(yvalues[:17], randomTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Time (mcs)")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)

yvalues = list(range(3, 36))
line, = ax.plot(yvalues, randomFullCount, color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, randomHalfCount, color='red', lw=2, label="half iteration")

chainTmp = randomHalfCount[16:]

line3, = ax.plot(yvalues[:17], chainTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Number of points")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)
yvalues = list(range(3, 36))

line, = ax.plot(yvalues, fullFullTime, color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, fullHalfTime, color='red', lw=2, label="half iteration")

fullTmp = fullHalfTime[16:]

line3, = ax.plot(yvalues[:17], fullTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Time (mcs)")

ax.set_yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
ax = fig.add_subplot(2, 1, 1)

yvalues = list(range(3, 36))
line, = ax.plot(yvalues, fullFullCount, color='blue', lw=2, label="full iteration")

line2, = ax.plot(yvalues, fullHalfCount, color='red', lw=2, label="half iteration")

chainTmp = fullHalfCount[16:]

line3, = ax.plot(yvalues[:17], chainTmp, color='green', lw=2, label="half iteration (shifted)")

ax.legend(loc="upper left", prop={'size': 25})
plt.xlabel("Depth of graph")
plt.ylabel("Number of points")

ax.set_yscale('log')
plt.show()
